# %%
def tokens_from_file(name_of_file):
    file = open(name_of_file, "r")
    word = ""
    list1 = []
    list2 = []
    i = 0
    read = False
    with file as fileobj:
        for line in fileobj:
            for ch in line:
                if ch == "\'" and read == False:
                    read = True
                    i+=1
                    continue
                if read == True and ch == "\'":
                    read = False
                    if i % 2 == 0:
                        list1.append(word)
                    elif i % 2 != 0:
                        list2.append(word)
                    word = ""
                if(read == True):
                    word += ch
    zipped = zip(list1, list2)
    file.close()
    return list(zipped)

def access_to_touple(tokens):
    for item in tokens:
        print ("A tuple", item)
    #for a, b in tokens:
    #    print ("First", a, "then", b)
    #print(tokens[1])

# %%
iterator = 0

def empatar():
    global iterator
    iterator=iterator + 1

# Class -> Class_Definition Attribute_Definition Functions
def classs(tokens):
    res = False
    if class_definition(tokens) and attribute_definition and functions:
        res = True
    return res        
    
# Class_Definition -> Noun "ASSIGN" "CLASS"
def class_definition(tokens):
    if noun(tokens):
        if tokens[iterator][0] == "ASSIGN":
            empatar()
            if tokens[iterator][0] == "CLASS":
                empatar()
                return True
    return False

# Attribute_Definition -> "PRP" "OWN" Attribute_Cycle
def attribute_definition(tokens):
    if tokens[iterator][0] == "PRP":
        empatar()
        if tokens[iterator][0] == "VBD":
            empatar()
            if atribute(tokens):
                return True
    return False

#Attribute_Cycle -> Attribute [ "," Attribute_Cycle ]
def attribute_Cycle(tokens):
    res =  False
    if attibute(tokens):
        res = True
        if tokens[iterator][0] == ",":
            empatar()
            res = False
            if Attribute_Cycle(tokens):
                res = True
    return res

# Attribute -> Noun [ "ASSIGN" ( Number | String | Boolean | Pair | Array ) ]
def attribute(tokens):
    res = False
    if noun(tokens):
        res = True
        if tokens[iterator][0] == "ASSIGN":
            empatar()
            if string(tokens) or number(tokens) or boolean(tokens) or pair(tokens) or aray(tokens):
                res = True
            else:
                res = False
    return res

# Functions -> Function_Declarations Function_Definition_Cycle
def functions(tokens):
    res = False
    if function_declaration(tokens) and function_definition_cycle(tokens):
        res = True
    return res

# Function_Declarations -> "PRP" NounCycle
def function_declaration(tokens):
    res = False
    if tokens[iterator][0] == "PRP":
        empatar()
        if tokens[iterator][0] == "MD":
            empatar()
            if proper_noun_cycle(tokens):
                res = True
    return res

# Function_Definition_Cycle -> Function_Definition [ "," Function_Definition_Cycle ]
def function_definition_cicle(tokens):
    res = False
    res = function_definition(tokens)
    if tokens[iterator][0] == ",":
        empatar()
        res = function_definition_cicle(tokens)
    return res

# Function_Definition_Cycle -> Function_Definition [ "," Function_Definition_Cycle ]
def function_definition(tokens):
    res = False
    if tokens[iterator][0] == "TO":
        empatar()
        if noun(tokens):
            function_parameters(tokens)
            if function_body(tokens) or function_print(tokens):
                res = True
    return res

# Function_Parameters -> "PRP" "PARAMVERB" NounCycle
def function_parameters(tokens):
    res = False
    if tokens[iterator][0] == "PRP":
        empatar()
        if tokens[iterator][0] == "PARAMVERB":
            empatar()
            if proper_noun_cycle(tokens):
                res = True
    return res

# Function_Print -> "PRINT" AnyTokenCycle
def function_print(tokens):
    res = False
    if tokens[iterator][0] == "PRINT":
        empatar()
        res = any_token_cycle(tokens)
    return res

# Function_Body -> "PRP" "BODYVERB" FBody_Cycle [ "RETURN" Basic_Type ]
def function_body(tokens):
    res = False
    if tokens[iterator][0] == "PRP":
        empatar()
        if tokens[iterator][0] == "BODYVERB":
            empatar()
            res = f_Body_cycle(tokens)
            if tokens[iterator][0] == "RETURN":
                empatar()
                res = basic(tokens)
    return res

# FBody_Cycle -> ( Function_Call | Action ) [ "," FBody_Cycle ]
def f_Body_cycle(tokens):
    res = False
    if function_call(tokens) or action(tokens):
        res = True
        if tokens[iterator][0] == ",":
            empatar()
            res = f_Body_cycle(tokens)
    return res

# Function_Call -> Noun [ "PARL" [ any_basic ] "PARR" ]
def function_call(tokens):
    res = False
    if noun(tokens):
        res = True
        if tokens[iterator][0] == "PARL":
            empatar()
            argument_Cycle(tokens)
            if tokens[iterator][0] == "PARR":
                empatar()
                res = True
    return res

# AnyTokenCycle -> AnyToken [ AnyTokenCycle ]
def any_token_cycle(tokens):
    res = False
    if any_token(tokens):
        res = True
    return res


# AnyToken -> (All tokens until "," or End of Sentence)
def any_token(tokens):
    res = True
    while tokens[iterator][0] != "," or tokens[iterator][0] != "PTRSTOP":
            empatar()
    empatar()
    return res
        
# proper_noun_cycle -> Noun [ "," proper_noun_cycle ]
def proper_noun_cycle(tokens):
    res = False
    if noun(tokens):
        res = True
        if tokens[iterator][0] == ",":
            res = False
            if proper_noun_cycle(tokens):
                res = True
    return res

# any_basic -> Basic_Type [ "," any_basic ]
def any_basic(tokens):
    res = False
    if basic(tokens):
        res = True
        if tokens[iterator][0] == ",":
            empatar()
            res = any_basic(tokens)
    return res

# Action -> ( "ADD" | "SUBSTRACT" | "ASSIGN" ) Basic_Type
def action(tokens):
    res = False
    if tokens[iterator][0] == "ADD" or tokens[iterator][0] == "SUBSTRACT" or tokens[iterator][0] == "ASSIGN":
        empatar()
        res = basic(tokens)
    return res

# Basic_Type -> Number | String | Noun | Boolean
def basic(tokens):
    res = False
    if string(tokens) or boolean(tokens) or number(tokens) or noun(tokens):
        res = True
    return res

# Noun -> "NN" | "NNP"
def noun(tokens):
    res = False
    if tokens[iterator][0] == "NNP" or tokens[iterator][0] == "NN":
        empatar()
        res = True
    return res    

# String -> "STRSTART [ Content ] STRSTOP"
def string(tokens):
    res = False
    if tokens[iterator][0] == "STRSTART":
        empatar()
        try:
            while(tokens[iterator][0] != "STRSTOP"):
                empatar()
        except IndexError:
            print("fuera de indice")
            return False
        empatar()
        res = True
    return res

# Number -> "CD"
def number(tokens):
    res = False
    if tokens[iterator][0] == "CD":
        empatar()
        res = True
    return res

# Boolean -> "TRUE" | "FALSE"
def boolean(tokens):
    res = False
    if tokens[iterator][0] == "BOOLEAN":
        empatar()
        res = True
    return res

# Pair -> "PARL" "CD" "PARR"
def pair(tokens):
    res = False
    if tokens[iterator][0] == "PARL":
        empatar()
        if number(tokens) and tokens[iterator][0] == "CD":
            empatar()
            if number(tokens) and tokens[iterator][0] == "PARR":
                empatar()
                res = True
    return res

# Array -> "BRACKL" "CD" "BRACKR"
def aray(tokens):
    res = False
    if tokens[iterator][0] == "BRACKL":
        empatar()
        if number(tokens) and tokens[iterator][0] == "CD":
            empatar()
            if tokens[iterator][0] == "BRACKR":
                empatar()
                res = True
    return res

def access_to_sintactico(source):
    for sentence in source:
        classs(tokens)
        
        
if __name__ == "__main__":
    name_of_file = "tokens.txt"
    tokens  = tokens_from_file(name_of_file)
    access_to_touple(tokens)
    print(tokens)
    print(classs(tokens))
# Out:
# A tuple ('NN', 'dog')
# A tuple ('ASSIGN', 'is')
# A tuple ('CLASS', 'Class')
# A tuple ('PRP', 'He')
# A tuple ('OWN', 'ha')
# A tuple ('NN', 'mood')
# A tuple ('ASSIGN', '=')
# A tuple ('STRSTART', '``')
# A tuple ('NNP', 'HAPPY')
# A tuple ('STRSTOP', '')
# A tuple (',', ',')
# A tuple ('NN', 'energy')
# A tuple ('ASSIGN', '=')
# A tuple ('CD', '100')
# A tuple (',', ',')
# A tuple ('NNP', 'coordenatePosition')
# A tuple ('ASSIGN', '=')
# A tuple ('PARL', '(')
# A tuple ('CD', '0,0')
# A tuple ('PARR', ')')
# A tuple ('PRP', 'He')
# A tuple ('NNP', 'Bark')
# A tuple (',', ',')
# A tuple ('NNP', 'Run')
# A tuple (',', ',')
# A tuple ('NNP', 'MoveLeft')
# A tuple (',', ',')
# A tuple ('NNP', 'MoveRight')
# A tuple (',', ',')
# A tuple ('NNP', 'MoveForward')
# A tuple (',', ',')
# A tuple ('NNP', 'Lay')
# A tuple (',', 'and')
# A tuple ('NNP', 'Check')
# A tuple ('TO', 'To')
# A tuple ('NNP', 'Run')
# A tuple ('PRP', 'he')
# A tuple ('BODYVERB', 'used')
# ...

# %%
par = [0,1,2,3,4,5]

for x in par:
    print(x)
try:
    par[6]
except IndexError:
    print("fuera de indice")
print("despues de catch")
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# fuera de indice
# despues de catch

# %% [markdown]
# ```Class -> Class_Definition Attribute_Definition Functions
# Class_Definition -> Noun "ASSIGN" "CLASS"
# Attribute_Definition -> "PRP" "OWN" Attribute_Cycle
# Attribute_Cycle -> Attribute [ "," Attribute_Cycle ]
# Attribute -> Noun [ "ASSIGN" ( Number | String | Boolean | Pair | Array ) ]
# Functions -> Function_Declarations Function_Definition_Cycle
# Function_Declarations -> "PRP" proper_noun_cycle
# Function_Definition_Cycle -> Function_Definition [ "," Function_Definition_Cycle ]
# Function_Definition -> "TO" Noun [Function_Parameters] ( Function_Body | Function_Print)
# Function_Parameters -> "PRP" "PARAMVERB" proper_noun_cycle
# Function_Print -> "PRINT" AnyTokenCycle
# Function_Body -> "PRP" "BODYVERB" FBody_Cycle [ "RETURN" Basic_Type ]
# FBody_Cycle -> ( Function_Call | Action ) [ "," FBody_Cycle ]
# Function_Call -> Noun [ "PARL" [ any_basic ] "PARR" ]
# AnyTokenCycle -> AnyToken [ AnyTokenCycle ]
# AnyToken -> (All tokens until "," or End of Sentence)
# proper_noun_cycle -> Noun [ "," proper_noun_cycle ]
# any_basic -> Basic_Type [ "," any_basic ]
# Action -> ( "ADD" | "SUBSTRACT" | "ASSIGN" ) Basic_Type
# Basic_Type -> Number | String | Noun | Boolean
# Noun -> "NN" | "NNP"
# Number -> "CD"
# String -> "STRSTART [ Content ] STRSTOP"
# Content -> ( anything found inside is valid until STRSTOP is found )
# Boolean -> "TRUE" | "FALSE"
# Pair -> "PARL" "CD" "PARR"
# Array -> "BRACKL" "CD" "BRACKR"```
